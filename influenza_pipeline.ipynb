# %%
# !mv sratoolkit.3.2.1-ubuntu64 sratoolkit

# %%
# !pip install rpy2==3.5.11
# Out:
# Collecting rpy2==3.5.11
#   Downloading rpy2-3.5.11.tar.gz (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 6.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from rpy2==3.5.11) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from rpy2==3.5.11) (3.1.6)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from rpy2==3.5.11) (2025.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.12/dist-packages (from rpy2==3.5.11) (5.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.10.0->rpy2==3.5.11) (2.23)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->rpy2==3.5.11) (3.0.3)
# Building wheels for collected packages: rpy2
#   Building wheel for rpy2 (pyproject.toml) ... done
#   Created wheel for rpy2: filename=rpy2-3.5.11-cp312-cp312-linux_x86_64.whl size=329394 sha256=071e013b5ba3ef1ebc2dddfad296f77ab71b5d4acdc77471e06b7544279fed46
#   Stored in directory: /root/.cache/pip/wheels/ba/57/02/525c617e5b7a31cf1bb1f04245a1e53a66b3a15ab073637e15
# Successfully built rpy2
# Installing collected packages: rpy2
#   Attempting uninstall: rpy2
#     Found existing installation: rpy2 3.5.17
#     Uninstalling rpy2-3.5.17:
#       Successfully uninstalled rpy2-3.5.17
# Successfully installed rpy2-3.5.11

# %%
# %load_ext rpy2.ipython

# %%
import os
os.environ['PATH'] += ":/content/sratoolkit/bin"

# %%
# !wget https://github.com/COMBINE-lab/salmon/releases/download/v1.9.0/salmon-1.9.0_linux_x86_64.tar.gz
# !tar -xzf salmon-1.9.0_linux_x86_64.tar.gz
# !mv salmon-1.9.0_linux_x86_64 salmon
# Out:
# --2025-11-20 21:01:56--  https://github.com/COMBINE-lab/salmon/releases/download/v1.9.0/salmon-1.9.0_linux_x86_64.tar.gz
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/32549942/3bc9e9b8-c773-451d-8dbe-fbb7726a71c5?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-11-20T22%3A00%3A42Z&rscd=attachment%3B+filename%3Dsalmon-1.9.0_linux_x86_64.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-11-20T20%3A59%3A43Z&ske=2025-11-20T22%3A00%3A42Z&sks=b&skv=2018-11-09&sig=e2IeCoawLFG0UkzH7FHHGfbuXklXcTpNxIFmge9Xd%2Fw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MzY3NDMxNywibmJmIjoxNzYzNjcyNTE3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.2OEoE_tYbBjHCSPSuYA8inYWiSW-cixBRyIJpMkIwLM&response-content-disposition=attachment%3B%20filename%3Dsalmon-1.9.0_linux_x86_64.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-11-20 21:01:57--  https://release-assets.githubusercontent.com/github-production-release-asset/32549942/3bc9e9b8-c773-451d-8dbe-fbb7726a71c5?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-11-20T22%3A00%3A42Z&rscd=attachment%3B+filename%3Dsalmon-1.9.0_linux_x86_64.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-11-20T20%3A59%3A43Z&ske=2025-11-20T22%3A00%3A42Z&sks=b&skv=2018-11-09&sig=e2IeCoawLFG0UkzH7FHHGfbuXklXcTpNxIFmge9Xd%2Fw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MzY3NDMxNywibmJmIjoxNzYzNjcyNTE3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.2OEoE_tYbBjHCSPSuYA8inYWiSW-cixBRyIJpMkIwLM&response-content-disposition=attachment%3B%20filename%3Dsalmon-1.9.0_linux_x86_64.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95797815 (91M) [application/octet-stream]
# Saving to: ‘salmon-1.9.0_linux_x86_64.tar.gz’
#
# salmon-1.9.0_linux_ 100%[===================>]  91.36M  43.8MB/s    in 2.1s
#
# 2025-11-20 21:01:59 (43.8 MB/s) - ‘salmon-1.9.0_linux_x86_64.tar.gz’ saved [95797815/95797815]

# %%
import os
os.environ['PATH'] += ":/content/salmon/bin"

# %%
# !tar -xzf salmon-1.9.0_linux_x86_64.tar.gz

# %%
# !ls
# Out:
# salmon				  sample_data
# salmon-1.9.0_linux_x86_64	  sratoolkit
# salmon-1.9.0_linux_x86_64.tar.gz  sratoolkit.current-ubuntu64.tar.gz

# %%
import os
os.environ['PATH'] += ":/content/salmon/bin"

# %%
# !salmon --version
# Out:
# salmon 1.9.0

# %%
# !bash -c 'for id in SRR12485106 SRR12485107 SRR12485108 SRR12485109 SRR12485110 SRR12485111 SRR12485112 SRR12485113; do fastq-dump --split-files $id; done'
# Out:
# Rejected 6156111 READS because READLEN < 1
# Read 6156111 spots for SRR12485106
# Written 6156111 spots for SRR12485106
# Rejected 4795564 READS because READLEN < 1
# Read 4795564 spots for SRR12485107
# Written 4795564 spots for SRR12485107
# Rejected 4738547 READS because READLEN < 1
# Read 4738547 spots for SRR12485108
# Written 4738547 spots for SRR12485108
# Rejected 4867237 READS because READLEN < 1
# Read 4867237 spots for SRR12485109
# Written 4867237 spots for SRR12485109
# Rejected 4787345 READS because READLEN < 1
# Read 4787345 spots for SRR12485110
# Written 4787345 spots for SRR12485110
# Rejected 4726232 READS because READLEN < 1
# Read 4726232 spots for SRR12485111
# Written 4726232 spots for SRR12485111
# Rejected 4864268 READS because READLEN < 1
# Read 4864268 spots for SRR12485112
# Written 4864268 spots for SRR12485112
# Rejected 4512372 READS because READLEN < 1
# Read 4512372 spots for SRR12485113
# Written 4512372 spots for SRR12485113

# %%
# !wget https://ftp.ensembl.org/pub/release-110/fasta/homo_sapiens/cdna/Homo_sapiens.GRCh38.cdna.all.fa.gz
# !gunzip Homo_sapiens.GRCh38.cdna.all.fa.gz

# !salmon index -t Homo_sapiens.GRCh38.cdna.all.fa -i hs_index
# Out:
# --2025-11-20 21:14:53--  https://ftp.ensembl.org/pub/release-110/fasta/homo_sapiens/cdna/Homo_sapiens.GRCh38.cdna.all.fa.gz
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78889691 (75M) [application/x-gzip]
# Saving to: ‘Homo_sapiens.GRCh38.cdna.all.fa.gz’
#
# Homo_sapiens.GRCh38 100%[===================>]  75.23M  20.3MB/s    in 3.7s
#
# 2025-11-20 21:14:58 (20.3 MB/s) - ‘Homo_sapiens.GRCh38.cdna.all.fa.gz’ saved [78889691/78889691]
#
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# index ["hs_index"] did not previously exist  . . . creating it
# [2025-11-20 21:15:05.071] [jLog] [warning] The salmon index is being built without any decoy sequences.  It is recommended that decoy sequence (either computed auxiliary decoy sequence or the genome of the organism) be provided during indexing. Further details can be found at https://salmon.readthedocs.io/en/latest/salmon.html#preparing-transcriptome-indices-mapping-based-mode.
# [2025-11-20 21:15:05.071] [jLog] [info] building index
# out : hs_index
# [2025-11-20 21:15:05.076] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2025-11-20 21:15:05.090] [puff::index::jointLog] [warning] Entry with header [ENST00000415118.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000448914.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000434970.2], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000631435.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000632684.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000710614.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000605284.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000604642.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000603077.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000604446.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000604102.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000603693.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000604950.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000604838.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000603935.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000632524.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000633009.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000634070.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000632963.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000633030.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000633765.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000632619.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000632968.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000633159.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000631871.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000633010.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000632473.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000631884.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000632859.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000631895.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000634154.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000632609.2], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000632911.2], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000633504.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000632304.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000632542.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000633968.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000634085.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000633353.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000631803.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000633210.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000603326.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000439842.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000390567.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000452198.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000390569.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000437320.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000390571.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000390572.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000450276.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000390574.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000390575.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.091] [puff::index::jointLog] [warning] Entry with header [ENST00000431870.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000390578.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000451044.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000390580.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000390581.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000431440.2], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000390585.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000430425.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000454691.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000390588.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000414852.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000390590.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000390591.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000454908.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000390583.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:05.092] [puff::index::jointLog] [warning] Entry with header [ENST00000390584.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:06.736] [puff::index::jointLog] [warning] Entry with header [ENST00000626807.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:07.175] [puff::index::jointLog] [warning] Entry with header [ENST00000629250.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:07.338] [puff::index::jointLog] [warning] Entry with header [ENST00000632054.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:09.048] [puff::index::jointLog] [warning] Entry with header [ENST00000417283.5], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:09.048] [puff::index::jointLog] [warning] Entry with header [ENST00000465958.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:09.773] [puff::index::jointLog] [warning] Entry with header [ENST00000437226.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:18.656] [puff::index::jointLog] [warning] Entry with header [ENST00000692460.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:23.169] [puff::index::jointLog] [warning] Entry with header [ENST00000682202.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:26.085] [puff::index::jointLog] [warning] Entry with header [ENST00000632342.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:26.086] [puff::index::jointLog] [warning] Entry with header [ENST00000518246.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:26.422] [puff::index::jointLog] [warning] Entry with header [ENST00000473810.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:26.439] [puff::index::jointLog] [warning] Entry with header [ENST00000543745.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:26.455] [puff::index::jointLog] [warning] Entry with header [ENST00000603775.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:26.485] [puff::index::jointLog] [warning] Entry with header [ENST00000579054.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:26.608] [puff::index::jointLog] [warning] Entry with header [ENST00000573437.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2025-11-20 21:15:26.620] [puff::index::jointLog] [warning] Entry with header [ENST00000634174.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2025-11-20 21:15:26.690] [puff::index::jointLog] [warning] Removed 13067 transcripts that were sequence duplicates of indexed transcripts.
# [2025-11-20 21:15:26.690] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2025-11-20 21:15:26.696] [puff::index::jointLog] [info] Replaced 100,005 non-ATCG nucleotides
# [2025-11-20 21:15:26.696] [puff::index::jointLog] [info] Clipped poly-A tails from 1,525 transcripts
# wrote 194135 cleaned references
# [2025-11-20 21:15:28.159] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2025-11-20 21:15:41.745] [puff::index::jointLog] [info] ntHll estimated 115888588 distinct k-mers, setting filter size to 2^31
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 2147483648
# Capacity = 2
# Files:
# hs_index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:2147483648
# Pass	Filling	Filtering
# 1	187	583
# 2	32	0
# True junctions count = 796713
# False junctions count = 1437188
# Hash table size = 2233901
# Candidate marks count = 12826703
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 1
# True marks count: 8105724
# Edges construction time: 39
# --------------------------------------------------------------------------------
# Distinct junctions = 796713
#
# TwoPaCo::buildGraphMain:: allocated with scalable_malloc; freeing.
# TwoPaCo::buildGraphMain:: Calling scalable_allocation_command(TBBMALLOC_CLEAN_ALL_BUFFERS, 0);
# allowedIn: 18
# Max Junction ID: 904287
# seen.size():7234305 kmerInfo.size():904288
# approximateContigTotalLength: 80962941
# counters for complex kmers:
# (prec>1 & succ>1)=54955 | (succ>1 & isStart)=852 | (prec>1 & isEnd)=866 | (isStart & isEnd)=80
# contig count: 1195517 element count: 152591552 complex nodes: 56753
# # of ones in rank vector: 1195516
# [2025-11-20 21:30:17.732] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2025-11-20 21:30:17.732] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory hs_index
# size = 152591552
# -----------------------------------------
# | Loading contigs | Time = 33.781 ms
# -----------------------------------------
# size = 152591552
# -----------------------------------------
# | Loading contig boundaries | Time = 17.389 ms
# -----------------------------------------
# Number of ones: 1195516
# Number of ones per inventory item: 512
# Inventory entries filled: 2335
# 1195516
# [2025-11-20 21:30:18.293] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2025-11-20 21:30:18.320] [puff::index::jointLog] [info] contig count for validation: 1,195,516
# [2025-11-20 21:30:19.266] [puff::index::jointLog] [info] Total # of Contigs : 1,195,516
# [2025-11-20 21:30:19.266] [puff::index::jointLog] [info] Total # of numerical Contigs : 1,195,516
# [2025-11-20 21:30:19.420] [puff::index::jointLog] [info] Total # of contig vec entries: 8,156,827
# [2025-11-20 21:30:19.420] [puff::index::jointLog] [info] bits per offset entry 23
# [2025-11-20 21:30:20.124] [puff::index::jointLog] [info] Done constructing the contig vector. 1195517
# [2025-11-20 21:30:21.108] [puff::index::jointLog] [info] # segments = 1,195,516
# [2025-11-20 21:30:21.108] [puff::index::jointLog] [info] total length = 152,591,552
# [2025-11-20 21:30:21.464] [puff::index::jointLog] [info] Reading the reference files ...
# [2025-11-20 21:30:24.034] [puff::index::jointLog] [info] positional integer width = 28
# [2025-11-20 21:30:24.034] [puff::index::jointLog] [info] seqSize = 152,591,552
# [2025-11-20 21:30:24.034] [puff::index::jointLog] [info] rankSize = 152,591,552
# [2025-11-20 21:30:24.034] [puff::index::jointLog] [info] edgeVecSize = 0
# [2025-11-20 21:30:24.034] [puff::index::jointLog] [info] num keys = 116,726,072
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  100  %   elapsed:   0 min 37 sec   remaining:   0 min 0  sec
# Bitarray       611612992  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# [2025-11-20 21:31:00.919] [puff::index::jointLog] [info] mphf size = 72.91 MB
# [2025-11-20 21:31:01.185] [puff::index::jointLog] [info] chunk size = 76,295,776
# [2025-11-20 21:31:01.185] [puff::index::jointLog] [info] chunk 0 = [0, 76,295,776)
# [2025-11-20 21:31:01.185] [puff::index::jointLog] [info] chunk 1 = [76,295,776, 152,591,522)
# [2025-11-20 21:31:59.068] [puff::index::jointLog] [info] finished populating pos vector
# [2025-11-20 21:31:59.068] [puff::index::jointLog] [info] writing index components
# [2025-11-20 21:32:00.300] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2025-11-20 21:32:00.467] [jLog] [info] done building index

# %%
# !bash -c 'for s in SRR12485106 SRR12485107 SRR12485108 SRR12485109 SRR12485110 SRR12485111 SRR12485112 SRR12485113; do \
    mkdir -p ${s}_quant; \
    salmon quant -i hs_index -l A -r ${s}_1.fastq -p 4 -o ${s}_quant; \
done'
# Out:
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ### salmon (selective-alignment-based) v1.9.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { hs_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { SRR12485106_1.fastq }
# ### [ threads ] => { 4 }
# ### [ output ] => { SRR12485106_quant }
# Logs will be written to SRR12485106_quant/logs
# [2025-11-20 21:40:58.482] [jointLog] [info] setting maxHashResizeThreads to 4
# [2025-11-20 21:40:58.482] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2025-11-20 21:40:58.482] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2025-11-20 21:40:58.482] [jointLog] [info] Setting consensusSlack to selective-alignment default of 0.35.
# [2025-11-20 21:40:58.482] [jointLog] [info] parsing read library format
# [2025-11-20 21:40:58.482] [jointLog] [info] There is 1 library.
# [2025-11-20 21:40:58.482] [jointLog] [info] Loading pufferfish index
# [2025-11-20 21:40:58.482] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 342.53 ms
# -----------------------------------------
# size = 1195517
# -----------------------------------------
# | Loading contig offsets | Time = 2.7573 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 654.91 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 57.985 ms
# -----------------------------------------
# size = 152591552
# Number of ones: 1195516
# Number of ones per inventory item: 512
# Inventory entries filled: 2335
# -----------------------------------------
# | Loading contig boundaries | Time = 320.04 ms
# -----------------------------------------
# size = 152591552
# -----------------------------------------
# | Loading sequence | Time = 27.56 ms
# -----------------------------------------
# size = 116726072
# -----------------------------------------
# | Loading positions | Time = 310.02 ms
# -----------------------------------------
# size = 372349075
# -----------------------------------------
# | Loading reference sequence | Time = 76.998 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 1.2529 ms
# -----------------------------------------
# [2025-11-20 21:40:59.623] [jointLog] [info] done
# [2025-11-20 21:40:59.717] [jointLog] [info] Index contained 194,182 targets
# [2025-11-20 21:40:59.875] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2025-11-20 21:41:01.852] [jointLog] [info] Automatically detected most likely library type as U
#
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# hits: 10,878,555; hits per frag:  1.81893
#
#
#
#
#
#
#
# TBB Warning: The number of workers is currently limited to 1. The request for 3 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
# [2025-11-20 21:47:28.957] [jointLog] [info] Computed 362,194 rich equivalence classes for further processing
# [2025-11-20 21:47:28.957] [jointLog] [info] Counted 730,771 total reads in the equivalence classes
# [2025-11-20 21:47:28.960] [jointLog] [info] Number of mappings discarded because of alignment score : 24,096,803
# [2025-11-20 21:47:28.960] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 97,330
# [2025-11-20 21:47:28.960] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2025-11-20 21:47:28.960] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2025-11-20 21:47:28.982] [jointLog] [warning] Only 730771 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2025-11-20 21:47:28.982] [jointLog] [info] Mapping rate = 11.8707%
#
# [2025-11-20 21:47:28.982] [jointLog] [info] finished quantifyLibrary()
# [2025-11-20 21:47:28.983] [jointLog] [info] Starting optimizer
# [2025-11-20 21:47:29.537] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2025-11-20 21:47:29.819] [jointLog] [info] iteration = 0 | max rel diff. = 366.151
# [2025-11-20 21:47:50.212] [jointLog] [info] iteration = 100 | max rel diff. = 5.46344
# [2025-11-20 21:48:11.273] [jointLog] [info] iteration = 200 | max rel diff. = 0.857701
# [2025-11-20 21:48:32.415] [jointLog] [info] iteration = 300 | max rel diff. = 0.48071
# [2025-11-20 21:48:53.507] [jointLog] [info] iteration = 400 | max rel diff. = 5.39075
# [2025-11-20 21:48:58.227] [jointLog] [info] iteration = 433 | max rel diff. = 0.00888811
# [2025-11-20 21:48:58.260] [jointLog] [info] Finished optimizer
# [2025-11-20 21:48:58.260] [jointLog] [info] writing output
#
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ### salmon (selective-alignment-based) v1.9.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { hs_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { SRR12485107_1.fastq }
# ### [ threads ] => { 4 }
# ### [ output ] => { SRR12485107_quant }
# Logs will be written to SRR12485107_quant/logs
# [2025-11-20 21:49:00.139] [jointLog] [info] setting maxHashResizeThreads to 4
# [2025-11-20 21:49:00.139] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2025-11-20 21:49:00.139] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2025-11-20 21:49:00.139] [jointLog] [info] Setting consensusSlack to selective-alignment default of 0.35.
# [2025-11-20 21:49:00.139] [jointLog] [info] parsing read library format
# [2025-11-20 21:49:00.139] [jointLog] [info] There is 1 library.
# [2025-11-20 21:49:00.139] [jointLog] [info] Loading pufferfish index
# [2025-11-20 21:49:00.139] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 574.32 ms
# -----------------------------------------
# size = 1195517
# -----------------------------------------
# | Loading contig offsets | Time = 3.8087 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 843.27 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 69.066 ms
# -----------------------------------------
# size = 152591552
# Number of ones: 1195516
# Number of ones per inventory item: 512
# Inventory entries filled: 2335
# -----------------------------------------
# | Loading contig boundaries | Time = 558.36 ms
# -----------------------------------------
# size = 152591552
# -----------------------------------------
# | Loading sequence | Time = 40.936 ms
# -----------------------------------------
# size = 116726072
# -----------------------------------------
# | Loading positions | Time = 409.31 ms
# -----------------------------------------
# size = 372349075
# -----------------------------------------
# | Loading reference sequence | Time = 92.059 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 1.5701 ms
# -----------------------------------------
#
#
#
#
# [2025-11-20 21:49:01.891] [jointLog] [info] done
# [2025-11-20 21:49:01.999] [jointLog] [info] Index contained 194,182 targets
# [2025-11-20 21:49:02.085] [jointLog] [info] Number of decoys : 0
# [2025-11-20 21:49:05.812] [jointLog] [info] Automatically detected most likely library type as U
#
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# hits: 7,798,002; hits per frag:  1.73606
#
#
#
#
#
#
#
# TBB Warning: The number of workers is currently limited to 1. The request for 3 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
# [2025-11-20 21:54:04.338] [jointLog] [info] Computed 262,434 rich equivalence classes for further processing
# [2025-11-20 21:54:04.338] [jointLog] [info] Counted 470,902 total reads in the equivalence classes
# [2025-11-20 21:54:04.340] [jointLog] [info] Number of mappings discarded because of alignment score : 17,127,277
# [2025-11-20 21:54:04.340] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 64,752
# [2025-11-20 21:54:04.340] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2025-11-20 21:54:04.340] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2025-11-20 21:54:04.362] [jointLog] [warning] Only 470902 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2025-11-20 21:54:04.362] [jointLog] [info] Mapping rate = 9.81953%
#
# [2025-11-20 21:54:04.362] [jointLog] [info] finished quantifyLibrary()
# [2025-11-20 21:54:04.362] [jointLog] [info] Starting optimizer
# [2025-11-20 21:54:04.679] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2025-11-20 21:54:04.796] [jointLog] [info] iteration = 0 | max rel diff. = 238.527
# [2025-11-20 21:54:18.916] [jointLog] [info] iteration = 100 | max rel diff. = 9.64017
# [2025-11-20 21:54:34.344] [jointLog] [info] iteration = 200 | max rel diff. = 0.334709
# [2025-11-20 21:54:52.212] [jointLog] [info] iteration = 300 | max rel diff. = 12.397
# [2025-11-20 21:55:07.783] [jointLog] [info] iteration = 400 | max rel diff. = 0.383429
# [2025-11-20 21:55:21.797] [jointLog] [info] iteration = 500 | max rel diff. = 0.708763
# [2025-11-20 21:55:22.255] [jointLog] [info] iteration = 504 | max rel diff. = 0.00381261
# [2025-11-20 21:55:22.291] [jointLog] [info] Finished optimizer
# [2025-11-20 21:55:22.291] [jointLog] [info] writing output
#
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ### salmon (selective-alignment-based) v1.9.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { hs_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { SRR12485108_1.fastq }
# ### [ threads ] => { 4 }
# ### [ output ] => { SRR12485108_quant }
# Logs will be written to SRR12485108_quant/logs
# [2025-11-20 21:55:24.232] [jointLog] [info] setting maxHashResizeThreads to 4
# [2025-11-20 21:55:24.232] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2025-11-20 21:55:24.232] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2025-11-20 21:55:24.232] [jointLog] [info] Setting consensusSlack to selective-alignment default of 0.35.
# [2025-11-20 21:55:24.232] [jointLog] [info] parsing read library format
# [2025-11-20 21:55:24.232] [jointLog] [info] There is 1 library.
# [2025-11-20 21:55:24.232] [jointLog] [info] Loading pufferfish index
# [2025-11-20 21:55:24.232] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 579.2 ms
# -----------------------------------------
# size = 1195517
# -----------------------------------------
# | Loading contig offsets | Time = 4.2561 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 1.0047 ms
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 72.496 ms
# -----------------------------------------
# size = 152591552
# Number of ones: 1195516
# Number of ones per inventory item: 512
# Inventory entries filled: 2335
# -----------------------------------------
# | Loading contig boundaries | Time = 533.29 ms
# -----------------------------------------
# size = 152591552
# -----------------------------------------
# | Loading sequence | Time = 44.221 ms
# -----------------------------------------
# size = 116726072
# -----------------------------------------
# | Loading positions | Time = 448.87 ms
# -----------------------------------------
# size = 372349075
# -----------------------------------------
# | Loading reference sequence | Time = 99.176 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 1.5516 ms
# -----------------------------------------
#
#
#
#
# [2025-11-20 21:55:26.018] [jointLog] [info] done
# [2025-11-20 21:55:26.128] [jointLog] [info] Index contained 194,182 targets
# [2025-11-20 21:55:26.230] [jointLog] [info] Number of decoys : 0
# [2025-11-20 21:55:29.865] [jointLog] [info] Automatically detected most likely library type as U
#
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# hits: 7,868,040; hits per frag:  1.75641
#
#
#
#
#
#
#
# TBB Warning: The number of workers is currently limited to 1. The request for 3 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
# [2025-11-20 22:00:22.340] [jointLog] [info] Computed 263,032 rich equivalence classes for further processing
# [2025-11-20 22:00:22.340] [jointLog] [info] Counted 470,516 total reads in the equivalence classes
# [2025-11-20 22:00:22.342] [jointLog] [info] Number of mappings discarded because of alignment score : 17,199,634
# [2025-11-20 22:00:22.342] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 64,309
# [2025-11-20 22:00:22.342] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2025-11-20 22:00:22.342] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2025-11-20 22:00:22.365] [jointLog] [warning] Only 470516 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2025-11-20 22:00:22.365] [jointLog] [info] Mapping rate = 9.92954%
#
# [2025-11-20 22:00:22.365] [jointLog] [info] finished quantifyLibrary()
# [2025-11-20 22:00:22.365] [jointLog] [info] Starting optimizer
# [2025-11-20 22:00:22.793] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2025-11-20 22:00:22.996] [jointLog] [info] iteration = 0 | max rel diff. = 238.848
# [2025-11-20 22:00:40.889] [jointLog] [info] iteration = 100 | max rel diff. = 13.2953
# [2025-11-20 22:00:58.909] [jointLog] [info] iteration = 200 | max rel diff. = 0.112575
# [2025-11-20 22:01:12.447] [jointLog] [info] iteration = 300 | max rel diff. = 0.071021
# [2025-11-20 22:01:13.925] [jointLog] [info] iteration = 308 | max rel diff. = 0.00657236
# [2025-11-20 22:01:13.961] [jointLog] [info] Finished optimizer
# [2025-11-20 22:01:13.961] [jointLog] [info] writing output
#
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ### salmon (selective-alignment-based) v1.9.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { hs_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { SRR12485109_1.fastq }
# ### [ threads ] => { 4 }
# ### [ output ] => { SRR12485109_quant }
# Logs will be written to SRR12485109_quant/logs
# [2025-11-20 22:01:16.060] [jointLog] [info] setting maxHashResizeThreads to 4
# [2025-11-20 22:01:16.060] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2025-11-20 22:01:16.060] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2025-11-20 22:01:16.060] [jointLog] [info] Setting consensusSlack to selective-alignment default of 0.35.
# [2025-11-20 22:01:16.060] [jointLog] [info] parsing read library format
# [2025-11-20 22:01:16.060] [jointLog] [info] There is 1 library.
# [2025-11-20 22:01:16.060] [jointLog] [info] Loading pufferfish index
# [2025-11-20 22:01:16.060] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 839.49 ms
# -----------------------------------------
# size = 1195517
# -----------------------------------------
# | Loading contig offsets | Time = 26.966 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 9.0716 ms
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 447.06 ms
# -----------------------------------------
# size = 152591552
# Number of ones: 1195516
# Number of ones per inventory item: 512
# Inventory entries filled: 2335
# -----------------------------------------
# | Loading contig boundaries | Time = 523.05 ms
# -----------------------------------------
# size = 152591552
# -----------------------------------------
# | Loading sequence | Time = 141.14 ms
# -----------------------------------------
# size = 116726072
# -----------------------------------------
# | Loading positions | Time = 642.62 ms
# -----------------------------------------
# size = 372349075
# -----------------------------------------
# | Loading reference sequence | Time = 426.06 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 3.4406 ms
# -----------------------------------------
# [2025-11-20 22:01:19.127] [jointLog] [info] done
#
#
#
#
# [2025-11-20 22:01:19.594] [jointLog] [info] Index contained 194,182 targets
# [2025-11-20 22:01:19.734] [jointLog] [info] Number of decoys : 0
# [2025-11-20 22:01:22.290] [jointLog] [info] Automatically detected most likely library type as U
#
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# hits: 7,962,245; hits per frag:  1.77444
#
#
#
#
#
#
#
# [2025-11-20 22:06:30.571] [jointLog] [info] Computed 269,731 rich equivalence classes for further processing
# [2025-11-20 22:06:30.571] [jointLog] [info] Counted 485,270 total reads in the equivalence classes
# [2025-11-20 22:06:30.574] [jointLog] [info] Number of mappings discarded because of alignment score : 17,853,035
# [2025-11-20 22:06:30.574] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 66,245
# [2025-11-20 22:06:30.574] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2025-11-20 22:06:30.574] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2025-11-20 22:06:30.598] [jointLog] [warning] Only 485270 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2025-11-20 22:06:30.598] [jointLog] [info] Mapping rate = 9.97013%
#
# [2025-11-20 22:06:30.598] [jointLog] [info] finished quantifyLibrary()
# [2025-11-20 22:06:30.598] [jointLog] [info] Starting optimizer
# TBB Warning: The number of workers is currently limited to 1. The request for 3 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
# [2025-11-20 22:06:47.822] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2025-11-20 22:06:47.998] [jointLog] [info] iteration = 0 | max rel diff. = 246.234
# [2025-11-20 22:07:04.401] [jointLog] [info] iteration = 100 | max rel diff. = 6.0079
# [2025-11-20 22:07:19.896] [jointLog] [info] iteration = 200 | max rel diff. = 0.339808
# [2025-11-20 22:07:35.204] [jointLog] [info] iteration = 300 | max rel diff. = 0.0253305
# [2025-11-20 22:07:44.906] [jointLog] [info] iteration = 344 | max rel diff. = 0.00882228
# [2025-11-20 22:07:44.944] [jointLog] [info] Finished optimizer
# [2025-11-20 22:07:44.944] [jointLog] [info] writing output
#
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ### salmon (selective-alignment-based) v1.9.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { hs_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { SRR12485110_1.fastq }
# ### [ threads ] => { 4 }
# ### [ output ] => { SRR12485110_quant }
# Logs will be written to SRR12485110_quant/logs
# [2025-11-20 22:07:47.028] [jointLog] [info] setting maxHashResizeThreads to 4
# [2025-11-20 22:07:47.028] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2025-11-20 22:07:47.028] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2025-11-20 22:07:47.028] [jointLog] [info] Setting consensusSlack to selective-alignment default of 0.35.
# [2025-11-20 22:07:47.028] [jointLog] [info] parsing read library format
# [2025-11-20 22:07:47.028] [jointLog] [info] There is 1 library.
# [2025-11-20 22:07:47.028] [jointLog] [info] Loading pufferfish index
# [2025-11-20 22:07:47.028] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 692.46 ms
# -----------------------------------------
# size = 1195517
# -----------------------------------------
# | Loading contig offsets | Time = 3.8216 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 997.17 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 82.872 ms
# -----------------------------------------
# size = 152591552
# Number of ones: 1195516
# Number of ones per inventory item: 512
# Inventory entries filled: 2335
# -----------------------------------------
# | Loading contig boundaries | Time = 383.3 ms
# -----------------------------------------
# size = 152591552
# -----------------------------------------
# | Loading sequence | Time = 29.854 ms
# -----------------------------------------
# size = 116726072
# -----------------------------------------
# | Loading positions | Time = 443.5 ms
# -----------------------------------------
# size = 372349075
# -----------------------------------------
# | Loading reference sequence | Time = 128.94 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 1.2796 ms
# -----------------------------------------
#
#
#
#
# [2025-11-20 22:07:48.797] [jointLog] [info] done
# [2025-11-20 22:07:48.880] [jointLog] [info] Index contained 194,182 targets
# [2025-11-20 22:07:48.945] [jointLog] [info] Number of decoys : 0
# [2025-11-20 22:07:50.646] [jointLog] [info] Automatically detected most likely library type as U
#
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# hits: 7,907,074; hits per frag:  1.76287
#
#
#
#
#
#
#
# TBB Warning: The number of workers is currently limited to 1. The request for 3 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
# [2025-11-20 22:12:40.548] [jointLog] [info] Computed 265,247 rich equivalence classes for further processing
# [2025-11-20 22:12:40.548] [jointLog] [info] Counted 476,398 total reads in the equivalence classes
# [2025-11-20 22:12:40.550] [jointLog] [info] Number of mappings discarded because of alignment score : 17,434,565
# [2025-11-20 22:12:40.550] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 64,967
# [2025-11-20 22:12:40.550] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2025-11-20 22:12:40.550] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2025-11-20 22:12:40.571] [jointLog] [warning] Only 476398 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2025-11-20 22:12:40.571] [jointLog] [info] Mapping rate = 9.95119%
#
# [2025-11-20 22:12:40.571] [jointLog] [info] finished quantifyLibrary()
# [2025-11-20 22:12:40.571] [jointLog] [info] Starting optimizer
# [2025-11-20 22:12:40.879] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2025-11-20 22:12:40.999] [jointLog] [info] iteration = 0 | max rel diff. = 241.841
# [2025-11-20 22:12:58.999] [jointLog] [info] iteration = 100 | max rel diff. = 8.89423
# [2025-11-20 22:13:12.247] [jointLog] [info] iteration = 200 | max rel diff. = 1.87481
# [2025-11-20 22:13:29.106] [jointLog] [info] iteration = 300 | max rel diff. = 0.126054
# [2025-11-20 22:13:47.225] [jointLog] [info] iteration = 400 | max rel diff. = 0.0298779
# [2025-11-20 22:13:53.209] [jointLog] [info] iteration = 451 | max rel diff. = 0.00746806
# [2025-11-20 22:13:53.242] [jointLog] [info] Finished optimizer
# [2025-11-20 22:13:53.242] [jointLog] [info] writing output
#
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ### salmon (selective-alignment-based) v1.9.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { hs_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { SRR12485111_1.fastq }
# ### [ threads ] => { 4 }
# ### [ output ] => { SRR12485111_quant }
# Logs will be written to SRR12485111_quant/logs
# [2025-11-20 22:13:54.781] [jointLog] [info] setting maxHashResizeThreads to 4
# [2025-11-20 22:13:54.781] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2025-11-20 22:13:54.781] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2025-11-20 22:13:54.781] [jointLog] [info] Setting consensusSlack to selective-alignment default of 0.35.
# [2025-11-20 22:13:54.781] [jointLog] [info] parsing read library format
# [2025-11-20 22:13:54.781] [jointLog] [info] There is 1 library.
# [2025-11-20 22:13:54.781] [jointLog] [info] Loading pufferfish index
# [2025-11-20 22:13:54.781] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 371.06 ms
# -----------------------------------------
# size = 1195517
# -----------------------------------------
# | Loading contig offsets | Time = 3.8214 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 798.76 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 82.793 ms
# -----------------------------------------
# size = 152591552
# Number of ones: 1195516
# Number of ones per inventory item: 512
# Inventory entries filled: 2335
# -----------------------------------------
# | Loading contig boundaries | Time = 526.73 ms
# -----------------------------------------
# size = 152591552
# -----------------------------------------
# | Loading sequence | Time = 37.619 ms
# -----------------------------------------
# size = 116726072
# -----------------------------------------
# | Loading positions | Time = 417.58 ms
# -----------------------------------------
# size = 372349075
# -----------------------------------------
# | Loading reference sequence | Time = 109.26 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 1.6508 ms
# -----------------------------------------
# [2025-11-20 22:13:56.334] [jointLog] [info] done
# [2025-11-20 22:13:56.432] [jointLog] [info] Index contained 194,182 targets
# [2025-11-20 22:13:56.518] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2025-11-20 22:14:00.074] [jointLog] [info] Automatically detected most likely library type as U
#
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# hits: 7,864,246; hits per frag:  1.75117
#
#
#
#
#
#
#
# [2025-11-20 22:18:55.225] [jointLog] [info] Computed 262,042 rich equivalence classes for further processing
# [2025-11-20 22:18:55.225] [jointLog] [info] Counted 467,671 total reads in the equivalence classes
# [2025-11-20 22:18:55.227] [jointLog] [info] Number of mappings discarded because of alignment score : 17,070,433
# [2025-11-20 22:18:55.227] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 63,958
# [2025-11-20 22:18:55.227] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2025-11-20 22:18:55.227] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2025-11-20 22:18:55.248] [jointLog] [warning] Only 467671 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2025-11-20 22:18:55.248] [jointLog] [info] Mapping rate = 9.89522%
#
# [2025-11-20 22:18:55.248] [jointLog] [info] finished quantifyLibrary()
# [2025-11-20 22:18:55.248] [jointLog] [info] Starting optimizer
# TBB Warning: The number of workers is currently limited to 1. The request for 3 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
# [2025-11-20 22:18:55.702] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2025-11-20 22:18:55.816] [jointLog] [info] iteration = 0 | max rel diff. = 237.063
# [2025-11-20 22:19:13.790] [jointLog] [info] iteration = 100 | max rel diff. = 2.0336
# [2025-11-20 22:19:26.938] [jointLog] [info] iteration = 200 | max rel diff. = 1.01581
# [2025-11-20 22:19:43.515] [jointLog] [info] iteration = 300 | max rel diff. = 0.140361
# [2025-11-20 22:20:01.463] [jointLog] [info] iteration = 400 | max rel diff. = 0.0503987
# [2025-11-20 22:20:04.669] [jointLog] [info] iteration = 428 | max rel diff. = 0.00616777
# [2025-11-20 22:20:04.701] [jointLog] [info] Finished optimizer
# [2025-11-20 22:20:04.701] [jointLog] [info] writing output
#
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ### salmon (selective-alignment-based) v1.9.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { hs_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { SRR12485112_1.fastq }
# ### [ threads ] => { 4 }
# ### [ output ] => { SRR12485112_quant }
# Logs will be written to SRR12485112_quant/logs
# [2025-11-20 22:20:06.170] [jointLog] [info] setting maxHashResizeThreads to 4
# [2025-11-20 22:20:06.170] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2025-11-20 22:20:06.170] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2025-11-20 22:20:06.170] [jointLog] [info] Setting consensusSlack to selective-alignment default of 0.35.
# [2025-11-20 22:20:06.170] [jointLog] [info] parsing read library format
# [2025-11-20 22:20:06.170] [jointLog] [info] There is 1 library.
# [2025-11-20 22:20:06.170] [jointLog] [info] Loading pufferfish index
# [2025-11-20 22:20:06.170] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 407.74 ms
# -----------------------------------------
# size = 1195517
# -----------------------------------------
# | Loading contig offsets | Time = 2.891 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 697.41 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 59.04 ms
# -----------------------------------------
# size = 152591552
# Number of ones: 1195516
# Number of ones per inventory item: 512
# Inventory entries filled: 2335
# -----------------------------------------
# | Loading contig boundaries | Time = 319.33 ms
# -----------------------------------------
# size = 152591552
# -----------------------------------------
# | Loading sequence | Time = 29.671 ms
# -----------------------------------------
# size = 116726072
# -----------------------------------------
# | Loading positions | Time = 310.16 ms
# -----------------------------------------
# size = 372349075
# -----------------------------------------
# | Loading reference sequence | Time = 67.072 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 1.3956 ms
# -----------------------------------------
# [2025-11-20 22:20:07.370] [jointLog] [info] done
# [2025-11-20 22:20:07.460] [jointLog] [info] Index contained 194,182 targets
# [2025-11-20 22:20:07.531] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2025-11-20 22:20:09.307] [jointLog] [info] Automatically detected most likely library type as U
#
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# hits: 7,883,421; hits per frag:  1.75605
#
#
#
#
#
#
#
# TBB Warning: The number of workers is currently limited to 1. The request for 3 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
# [2025-11-20 22:25:14.049] [jointLog] [info] Computed 269,206 rich equivalence classes for further processing
# [2025-11-20 22:25:14.049] [jointLog] [info] Counted 483,211 total reads in the equivalence classes
# [2025-11-20 22:25:14.052] [jointLog] [info] Number of mappings discarded because of alignment score : 17,779,867
# [2025-11-20 22:25:14.052] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 66,228
# [2025-11-20 22:25:14.052] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2025-11-20 22:25:14.052] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2025-11-20 22:25:14.078] [jointLog] [warning] Only 483211 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2025-11-20 22:25:14.078] [jointLog] [info] Mapping rate = 9.93389%
#
# [2025-11-20 22:25:14.078] [jointLog] [info] finished quantifyLibrary()
# [2025-11-20 22:25:14.079] [jointLog] [info] Starting optimizer
# [2025-11-20 22:25:14.639] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2025-11-20 22:25:14.919] [jointLog] [info] iteration = 0 | max rel diff. = 245.413
# [2025-11-20 22:25:28.515] [jointLog] [info] iteration = 100 | max rel diff. = 16.2271
# [2025-11-20 22:25:45.409] [jointLog] [info] iteration = 200 | max rel diff. = 0.212218
# [2025-11-20 22:26:03.713] [jointLog] [info] iteration = 300 | max rel diff. = 0.0185381
# [2025-11-20 22:26:19.430] [jointLog] [info] iteration = 400 | max rel diff. = 0.123351
# [2025-11-20 22:26:32.306] [jointLog] [info] iteration = 487 | max rel diff. = 0.00889025
# [2025-11-20 22:26:32.342] [jointLog] [info] Finished optimizer
# [2025-11-20 22:26:32.342] [jointLog] [info] writing output
#
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ### salmon (selective-alignment-based) v1.9.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { hs_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { SRR12485113_1.fastq }
# ### [ threads ] => { 4 }
# ### [ output ] => { SRR12485113_quant }
# Logs will be written to SRR12485113_quant/logs
# [2025-11-20 22:26:33.653] [jointLog] [info] setting maxHashResizeThreads to 4
# [2025-11-20 22:26:33.653] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2025-11-20 22:26:33.653] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2025-11-20 22:26:33.653] [jointLog] [info] Setting consensusSlack to selective-alignment default of 0.35.
# [2025-11-20 22:26:33.653] [jointLog] [info] parsing read library format
# [2025-11-20 22:26:33.653] [jointLog] [info] There is 1 library.
# [2025-11-20 22:26:33.654] [jointLog] [info] Loading pufferfish index
# [2025-11-20 22:26:33.654] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 336.27 ms
# -----------------------------------------
# size = 1195517
# -----------------------------------------
# | Loading contig offsets | Time = 2.9609 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 782.09 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 65.036 ms
# -----------------------------------------
# size = 152591552
# Number of ones: 1195516
# Number of ones per inventory item: 512
# Inventory entries filled: 2335
# -----------------------------------------
# | Loading contig boundaries | Time = 535.06 ms
# -----------------------------------------
# size = 152591552
# -----------------------------------------
# | Loading sequence | Time = 37.832 ms
# -----------------------------------------
# size = 116726072
# -----------------------------------------
# | Loading positions | Time = 417.56 ms
# -----------------------------------------
# size = 372349075
# -----------------------------------------
# | Loading reference sequence | Time = 104.98 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 8.9152 ms
# -----------------------------------------
# [2025-11-20 22:26:35.164] [jointLog] [info] done
# [2025-11-20 22:26:35.264] [jointLog] [info] Index contained 194,182 targets
# [2025-11-20 22:26:35.348] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2025-11-20 22:26:39.570] [jointLog] [info] Automatically detected most likely library type as U
#
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# hits: 7,846,076; hits per frag:  1.74828
#
#
#
#
#
#
#
# [2025-11-20 22:31:19.625] [jointLog] [info] Computed 251,465 rich equivalence classes for further processing
# [2025-11-20 22:31:19.625] [jointLog] [info] Counted 446,629 total reads in the equivalence classes
# [2025-11-20 22:31:19.627] [jointLog] [info] Number of mappings discarded because of alignment score : 16,229,588
# [2025-11-20 22:31:19.627] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 60,709
# [2025-11-20 22:31:19.627] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2025-11-20 22:31:19.627] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2025-11-20 22:31:19.648] [jointLog] [warning] Only 446629 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2025-11-20 22:31:19.648] [jointLog] [info] Mapping rate = 9.89788%
#
# [2025-11-20 22:31:19.648] [jointLog] [info] finished quantifyLibrary()
# [2025-11-20 22:31:19.648] [jointLog] [info] Starting optimizer
# TBB Warning: The number of workers is currently limited to 1. The request for 3 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
# [2025-11-20 22:31:20.045] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2025-11-20 22:31:20.173] [jointLog] [info] iteration = 0 | max rel diff. = 226.66
# [2025-11-20 22:31:37.667] [jointLog] [info] iteration = 100 | max rel diff. = 8.26369
# [2025-11-20 22:31:51.844] [jointLog] [info] iteration = 200 | max rel diff. = 0.0826325
# [2025-11-20 22:32:06.322] [jointLog] [info] iteration = 300 | max rel diff. = 0.0389795
# [2025-11-20 22:32:23.788] [jointLog] [info] iteration = 400 | max rel diff. = 0.0702275
# [2025-11-20 22:32:38.386] [jointLog] [info] iteration = 500 | max rel diff. = 0.0396782
# [2025-11-20 22:32:49.497] [jointLog] [info] iteration = 574 | max rel diff. = 0.00824593
# [2025-11-20 22:32:49.531] [jointLog] [info] Finished optimizer
# [2025-11-20 22:32:49.531] [jointLog] [info] writing output

# %%
# %%R
# # Install if needed
# if (!require("BiocManager")) install.packages("BiocManager", repos="https://cloud.r-project.org")
# BiocManager::install(c("tximport", "DESeq2"), ask=FALSE)
#
# library(tximport)
# library(DESeq2)
# library(ggplot2)
#
# # Names of samples
# samples <- c(
#   "SRR12485106","SRR12485107","SRR12485108","SRR12485109",
#   "SRR12485110","SRR12485111","SRR12485112","SRR12485113"
# )
#
# # Path to quant.sf files
# files <- file.path(getwd(), paste0(samples, "_quant"), "quant.sf")
# names(files) <- samples
#
# # Import quantification
# txi <- tximport(files, type="salmon", txOut=TRUE)
#
# # Sample metadata (first 4 mock, last 4 infected)
# coldata <- data.frame(
#   row.names = samples,
#   condition = factor(c(rep("mock", 4), rep("infected", 4)))
# )
#
# # Build DESeq2 object
# dds <- DESeqDataSetFromTximport(txi, colData=coldata, design = ~ condition)
#
# # Normalization + VST
# dds <- DESeq(dds)
# vsd <- vst(dds)
#
# # PCA plot
# p <- plotPCA(vsd, intgroup="condition") +
#     ggtitle("PCA of A549 Influenza vs Mock") +
#     theme_bw(base_size = 14)
#
# # Save PCA plot
# ggsave("PCA_plot.png", plot = p, width = 6, height = 5)
#
# p
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: BiocManager
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/BiocManager_1.30.27.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 752490 bytes (734 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 734 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The downloaded source packages are in
# 	‘/tmp/RtmpDMnhlG/downloaded_packages’
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Bioconductor version 3.22 (BiocManager 1.30.27), R 4.5.2 (2025-10-31)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package(s) 'BiocVersion', 'tximport', 'DESeq2'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: also installing the dependencies ‘XVector’, ‘formatR’, ‘abind’, ‘SparseArray’, ‘lambda.r’, ‘futile.options’, ‘Seqinfo’, ‘S4Arrays’, ‘DelayedArray’, ‘futile.logger’, ‘snow’, ‘BH’, ‘S4Vectors’, ‘IRanges’, ‘GenomicRanges’, ‘SummarizedExperiment’, ‘BiocGenerics’, ‘Biobase’, ‘BiocParallel’, ‘matrixStats’, ‘locfit’, ‘MatrixGenerics’, ‘RcppArmadillo’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/XVector_0.50.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/formatR_1.14.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/abind_1.4-8.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/SparseArray_1.10.2.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/lambda.r_1.2.4.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/futile.options_1.0.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/Seqinfo_1.0.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/S4Arrays_1.10.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/DelayedArray_0.36.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/futile.logger_1.4.3.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/snow_0.4-4.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/BH_1.87.0-1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/S4Vectors_0.48.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/IRanges_2.44.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/GenomicRanges_1.62.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/SummarizedExperiment_1.40.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/BiocGenerics_0.56.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/Biobase_2.70.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/BiocParallel_1.44.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/matrixStats_1.5.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/locfit_1.5-9.12.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/MatrixGenerics_1.22.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/RcppArmadillo_15.0.2-2.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/BiocVersion_3.22.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/tximport_1.38.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://bioconductor.org/packages/3.22/bioc/src/contrib/DESeq2_1.50.2.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The downloaded source packages are in
# 	‘/tmp/RtmpDMnhlG/downloaded_packages’
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Old packages: 'digest', 'fansi', 'tinytex'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/digest_0.6.39.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/fansi_1.0.7.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/tinytex_0.58.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The downloaded source packages are in
# 	‘/tmp/RtmpDMnhlG/downloaded_packages’
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: S4Vectors
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: stats4
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: BiocGenerics
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: generics
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# Attaching package: ‘generics’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: IRanges
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: GenomicRanges
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: Seqinfo
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: SummarizedExperiment
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: MatrixGenerics
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: matrixStats
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# Attaching package: ‘MatrixGenerics’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: Biobase
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# Attaching package: ‘Biobase’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: reading in files with read_tsv
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 1
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 2
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 3
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 4
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 5
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 6
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 7
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 8
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: using counts and average transcript lengths from tximport
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: estimating size factors
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: using 'avgTxLength' from assays(dds), correcting for library size
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: estimating dispersions
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: gene-wise dispersion estimates
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: mean-dispersion relationship
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: final dispersion estimates
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: fitting model and testing
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: -- note: fitType='parametric', but the dispersion trend was not well captured by the
#    function: y = a/x + b, and a local regression fit was automatically substituted.
#    specify fitType='local' or 'mean' to avoid this message next time.
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: using ntop=500 top features by variance
